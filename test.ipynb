# %%
import torchvision 
from torchvision import transforms
import matplotlib.pyplot as plt
from PIL import Image
import glob

# %%
transform = transforms.Compose([
    transforms.RandomCrop((512,512), pad_if_needed=True),
    # transforms.RandomHorizontalFlip(),
    transforms.ToTensor(), # convert 0-255 to 0-1 and from np to tensors
    # transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
    transforms.ToPILImage()
])

# %%
class ImageFolderWithPaths(torchvision.datasets.ImageFolder):
    def __getitem__(self, index):
        img, label = super(ImageFolderWithPaths, self).__getitem__(index)
        path = self.imgs[index][0]
        return (img, label ,path)

# %%
image_list = glob.glob('/mnt/Enterprise2/shirshak/Glaucoma_Dataset_eyepacs_airogs_lightv2/eyepac-light-v2-512-jpg/*/*/*.jpg')
torchvision.io.read_image(image_list[2000]).shape
# Out:
# torch.Size([3, 512, 512])

# %%
dataset = ImageFolderWithPaths(path, transform=transform)

# %%
plt.imshow(Image.open(dataset[0][2]))

# %%
plt.imshow(dataset[0][0])

# %%
import torchvision

# %%
model = torchvision.models.resnet50(pretrained=True)
# Out:
# /home/shirshak/Glaucoma_Efficientnet_simple/.venv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/shirshak/Glaucoma_Efficientnet_simple/.venv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model.fc.in_features
# Out:
# 2048

# %%
import torch

# %%
outputs = torch.tensor([[0.2, 0.9]])

# %%
_, aa = torch.max(outputs, 1)
aa
# Out:
# tensor([1])

# %%
torch.tensor([[4.5389e-08, 1.0000e+00],
        [9.1468e-09, 1.0000e+00],
        [1.0000e+00, 6.0381e-08],
        [4.0763e-08, 1.0000e+00]])
# Out:
# tensor([[4.5389e-08, 1.0000e+00],
#         [9.1468e-09, 1.0000e+00],
#         [1.0000e+00, 6.0381e-08],
#         [4.0763e-08, 1.0000e+00]])
